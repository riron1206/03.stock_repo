# %% [markdown]
# # DBの株価確認

# %%
import pandas as pd
from pandas_highcharts.display import display_charts
# %matplotlib inline

import util

# スクエニ
code = 9684
df = util.fetch_prices_to_df(code)
df['5MA'] = df['close'].rolling(window=5).mean()
df['25MA'] = df['close'].rolling(window=25).mean()
df['100MA'] = df['close'].rolling(window=100).mean()
display(df.head())
display_charts(df[['close', '5MA', '25MA', '100MA']], chart_type='stock')
# Out:
# <script src="//code.highcharts.com/stock/highstock.js"></script>
# <script src="//code.highcharts.com/highcharts-more.js"></script>
# <script src="//code.highcharts.com/modules/exporting.js"></script>
#                    open         high          low        close      volume  \
# date
# 1999-08-18  3644.444444  4133.333333  3600.000000  4133.333333  1258647.75
# 1999-08-19  4000.000000  4133.333333  3915.555556  4000.000000  1349772.75
# 1999-08-20  3955.555556  4000.000000  3822.222222  3822.222222   416250.00
# 1999-08-23  3600.000000  3768.888889  3600.000000  3600.000000   356175.00
# 1999-08-24  3733.333333  3933.333333  3688.888889  3782.222222   399150.00
#
#                     5MA  25MA  100MA
# date
# 1999-08-18          NaN   NaN    NaN
# 1999-08-19          NaN   NaN    NaN
# 1999-08-20          NaN   NaN    NaN
# 1999-08-23          NaN   NaN    NaN
# 1999-08-24  3867.555556   NaN    NaN
# <div id="chart_idgzRorGub"</div>
#     <script type="text/javascript">new Highcharts.StockChart({"chart":{"renderTo":"chart_idgzRorGub"},"legend":{"enabled":true},"series":[{"name":"100MA","yAxis":0,"data":[[934934400000,null],[935020800000,null],[935107200000,null],[935366400000,null],[935452800000,null],[935539200000,null],[935625600000,null],[935712000000,null],[935971200000,null],[936057600000,null],[936144000000,null],[936230400000,null],[936316800000,null],[936576000000,null],[936662400000,null],[936748800000,null],[936835200000,null],[936921600000,null],[937180800000,null],[937267200000,null],[937440000000,null],[937526400000,null],[937785600000,null],[937872000000,null],[937958400000,null],[938131200000,null],[938390400000,null],[938476800000,null],[938563200000,null],[938649600000,null],[938736000000,null],[938995200000,null],[939081600000,null],[939168000000,null],[939254400000,null],[939340800000,null],[939686400000,null],[939772800000,null],[939859200000,null],[939945600000,null],[940204800000,null],[940291200000,null],[940377600000,null],[940464000000,null],[940550400000,null],[940809600000,null],[940896000000,null],[940982400000,null],[941068800000,null],[941155200000,null],[941414400000,null],[941500800000,null],[941673600000,null],[941760000000,null],[942019200000,null],[942105600000,null],[942192000000,null],[942278400000,null],[942364800000,null],[942624000000,null],[942710400000,null],[942796800000,null],[942883200000,null],[942969600000,null],[943228800000,null],[943401600000,null],[943488000000,null],[943574400000,null],[943833600000,null],[943920000000,null],[944006400000,null],[944092800000,null],[944179200000,null],[944438400000,null],[944524800000,null],[944611200000,null],[944697600000,null],[944784000000,null],[945043200000,null],[945129600000,null],[945216000000,null],[945302400000,null],[945388800000,null],[945648000000,null],[945734400000,null],[945820800000,null],[945993600000,null],[946252800000,null],[946339200000,null],[946425600000,null],[946512000000,null],[946944000000,null],[947030400000,null],[947116800000,null],[947203200000,null],[947548800000,null],[947635200000,null],[947721600000,null],[947808000000,null],[948067200000,4425.5555555556],[948153600000,4428.2222222222],[948240000000,4431.7333333333],[948326400000,4436.4888888889],[948412800000,4444.0444444444],[948672000000,4447.5555555556],[948758400000,4451.1555555556],[948844800000,4455.6],[948931200000,4455.6],[949017600000,4453.5111111111],[949276800000,4454.6222222222],[949363200000,4452.4444444444],[949449600000,4448.5777777778],[949536000000,4445.1555555556],[949622400000,4444.0444444444],[949881600000,4444.5333333333],[949968000000,4440.3555555556],[950054400000,4436.0444444444],[950140800000,4430.7555555556],[950486400000,4421.1555555556],[950572800000,4410.7555555556],[950659200000,4405.0222222222],[950745600000,4400.2666666667],[950832000000,4395.1555555556],[951091200000,4391.1555555556],[951177600000,4393.6444444444],[951264000000,4398.8],[951350400000,4406.5333333333],[951436800000,4410.8888888889],[951696000000,4412.4444444444],[951782400000,4413.8666666667],[951868800000,4413.8666666667],[951955200000,4414.1777777778],[952041600000,4413.7777777778],[952300800000,4412.9333333333],[952387200000,4411.2444444444],[952473600000,4411.6],[952560000000,4407.7777777778],[952646400000,4402.6222222222],[952905600000,4394.4],[952992000000,4389.5111111111],[953078400000,4393.4222222222],[953164800000,4392.9333333333],[953251200000,4389.1111111111],[953596800000,4386.9777777778],[953683200000,4384.9777777778],[953769600000,4382.0888888889],[953856000000,4379.3777777778],[954115200000,4376.9333333333],[954201600000,4372.8222222222],[954288000000,4369.9777777778],[954374400000,4365.8222222222],[954460800000,4361.4888888889],[954720000000,4354.8666666667],[954806400000,4344.1555555556],[954892800000,4334.4],[954979200000,4322.4888888889],[955065600000,4310.8444444444],[955324800000,4300.4666666667],[955411200000,4289.3333333333],[955497600000,4276.0444444444],[9555840000 ...

# %%
# JT
code = 2914
df = util.fetch_prices_to_df(code)
df['5MA'] = df['close'].rolling(window=5).mean()
df['25MA'] = df['close'].rolling(window=25).mean()
df['100MA'] = df['close'].rolling(window=100).mean()
display(df.head())
display_charts(df[['close', '5MA', '25MA', '100MA']], chart_type='stock')
# Out:
#               open    high     low   close    volume     5MA  25MA  100MA
# date
# 1994-10-27  1190.0  1200.0  1100.0  1100.0  40460000     NaN   NaN    NaN
# 1994-10-28  1060.0  1100.0  1050.0  1060.0  18334000     NaN   NaN    NaN
# 1994-10-31  1080.0  1090.0  1060.0  1080.0   5202000     NaN   NaN    NaN
# 1994-11-01  1090.0  1110.0  1080.0  1110.0   4821000     NaN   NaN    NaN
# 1994-11-02  1100.0  1110.0  1070.0  1080.0   4250000  1086.0   NaN    NaN
# <div id="chart_idNmwButKm"</div>
#     <script type="text/javascript">new Highcharts.StockChart({"chart":{"renderTo":"chart_idNmwButKm"},"legend":{"enabled":true},"series":[{"name":"100MA","yAxis":0,"data":[[783216000000,null],[783302400000,null],[783561600000,null],[783648000000,null],[783734400000,null],[783907200000,null],[784166400000,null],[784252800000,null],[784339200000,null],[784425600000,null],[784512000000,null],[784771200000,null],[784857600000,null],[784944000000,null],[785030400000,null],[785116800000,null],[785376000000,null],[785462400000,null],[785635200000,null],[785721600000,null],[785980800000,null],[786067200000,null],[786153600000,null],[786240000000,null],[786326400000,null],[786585600000,null],[786672000000,null],[786758400000,null],[786844800000,null],[786931200000,null],[787190400000,null],[787276800000,null],[787363200000,null],[787449600000,null],[787536000000,null],[787795200000,null],[787881600000,null],[787968000000,null],[788054400000,null],[788400000000,null],[788486400000,null],[788572800000,null],[788659200000,null],[788745600000,null],[789177600000,null],[789264000000,null],[789350400000,null],[789609600000,null],[789696000000,null],[789782400000,null],[789868800000,null],[789955200000,null],[790300800000,null],[790387200000,null],[790473600000,null],[790560000000,null],[790819200000,null],[790905600000,null],[790992000000,null],[791078400000,null],[791164800000,null],[791424000000,null],[791510400000,null],[791596800000,null],[791683200000,null],[791769600000,null],[792028800000,null],[792115200000,null],[792201600000,null],[792288000000,null],[792374400000,null],[792633600000,null],[792720000000,null],[792806400000,null],[792892800000,null],[792979200000,null],[793238400000,null],[793324800000,null],[793411200000,null],[793497600000,null],[793584000000,null],[793843200000,null],[793929600000,null],[794016000000,null],[794102400000,null],[794188800000,null],[794448000000,null],[794534400000,null],[794620800000,null],[794707200000,null],[794793600000,null],[795052800000,null],[795139200000,null],[795225600000,null],[795312000000,null],[795398400000,null],[795657600000,null],[795830400000,null],[795916800000,null],[796003200000,926.94],[796262400000,923.99],[796348800000,921.59],[796435200000,918.9],[796521600000,915.89],[796608000000,913.2],[796867200000,910.28],[796953600000,908.13],[797040000000,906.11],[797126400000,904.28],[797212800000,902.8],[797472000000,901.53],[797558400000,900.27],[797644800000,898.57],[797731200000,896.91],[797817600000,895.11],[798076800000,893.3],[798163200000,891.6],[798249600000,889.92],[798336000000,888.41],[798422400000,886.92],[798681600000,885.37],[798768000000,883.8],[798854400000,882.14],[798940800000,880.45],[799027200000,878.81],[799286400000,877.2],[799372800000,875.65],[799891200000,874.03],[799977600000,872.46],[800064000000,870.99],[800150400000,869.69],[800236800000,868.5],[800496000000,867.26],[800582400000,865.87],[800668800000,864.51],[800755200000,863.12],[800841600000,861.59],[801100800000,859.91],[801187200000,857.76],[801273600000,855.47],[801360000000,853.27],[801446400000,851.31],[801705600000,849.38],[801792000000,847.53],[801878400000,845.74],[801964800000,843.97],[802051200000,842.3],[802310400000,840.55],[802396800000,838.76],[802483200000,836.91],[802569600000,835.11],[802656000000,833.33],[802915200000,831.36],[803001600000,829.25],[803088000000,827.34],[803174400000,825.54],[803260800000,824.06],[803520000000,822.33],[803606400000,820.66],[803692800000,819.1],[803779200000,817.55],[803865600000,816.14],[804124800000,814.62],[804211200000,813.17],[804297600000,811.8],[804384000000,810.46],[804470400000,809.14],[804729600000,807.8],[804816000000,806.63],[804902400000,805.29],[804988800000,804.2],[805075200000,802.97],[805334400000,801.85],[805420800000,801.05],[805507200000,800.2],[805593600000,799.42],[805680000000,798.6],[805939200000,797.75],[806025600000,796.99],[806112000000,796.68],[806198400000,796.45],[806284800000,796.56],[806544000000,796.44],[806630400000,7 ...

# %% [markdown]
# #### import test

# %%
from create_db import no_000_create_db_tables
from create_db import no_010_get_brands_info
from create_db import no_020_kabuoji3_csv_download
from create_db import no_021_csv_to_db
from create_db import no_030_get_new_delete_brands_info
from create_db import no_040_csv_to_divide_union_data
from create_db import no_050_rating_data
from create_db import no_060_apply_divide_union_data
from create_db import no_070_quarterly_results

import util
import simulator
import golden_core30
import buy_and_hold
import rating_trade

import sys
sys.path.append(r'Git\japandas')
from japandas import japandas
print(japandas.__version__)
# Out:
# 0.5.1

# %% [markdown]
# #### tmp work

# %%
# %%time
# from create_db import no_060_apply_divide_union_data
# # 株価分割併合による株価更新処理失敗したとき用。70秒ぐらいでできる
# no_060_apply_divide_union_data.copy_prices_ratings_table()
# Out:
# Wall time: 1min 18s

# %%
# import sqlite3
# # 間違ったquarterly_results削除
# db_file_name = r'D:\DB_Browser_for_SQLite\stock.db'
# with sqlite3.connect(db_file_name) as conn:
#     conn.cursor().execute("DROP TABLE quarterly_results")

# %%
# %%time
# from create_db import no_070_quarterly_results
# # csvからquarterly_results再作成。10分ぐらいでできる
# no_070_quarterly_results.csv_to_quarterly_results_table()
